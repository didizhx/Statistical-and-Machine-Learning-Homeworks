# %%
#Dilda Zhaksybek. Homework for session 2.

# %% [markdown]
# # Exercise 2 (ch 2)

# %% [markdown]
# Exercise 2
#
# a) it is a regression problem as we need to identify which variables correlate with the CEO salary.
# n = 500 * number of employees
# p = 4 (profit, number of employees, indurstry and CEO salary)
# We are most interested in inference here.
#
# b) it is a classification problem, as we need to indentify the success or failure (1 or 0).
# n = 20
# p = 14
# We are most interested in prediciton here.
#
# c) Regression problem.
# n = number of weeks in 2021.
# p = 4.
# We are interested in prediction here.

# %% [markdown]
# # Exercise 10 (ch 2)

# %% [markdown]
# a) Boston dataset has:
# 506 rows, 14 columns.
# The dataset represents demographical data on the city of Boston:

# %%
library(MASS)
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08205   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %%
?Boston

# %%
#b)

#the higher the tax rate per $10,000 the higher is the crime rate per town. 
#Correlation rate of 0.58 suggests a positive correlation between these two variables
plot(Boston$tax, Boston$crim)
cor(Boston$tax, Boston$crim)
# Out:
# [1] 0.5827643
# plot without title

# %%
#Again, positive correlation here.
#The higher the non-retail business acres per town - the higher is the crime rate
plot(Boston$indus, Boston$crim)
cor(Boston$indus, Boston$crim)
# Out:
# [1] 0.4065834
# plot without title

# %%
# Here we can see that the higher the proportion of occupied old buildings - the higher the tax
cor(Boston$age, Boston$tax)
plot(Boston$age, Boston$tax)
# Out:
# [1] 0.5064556
# plot without title

# %%
#c) 
?Boston

cor(Boston$crim, Boston$black) #negative correlation, the higher the crime rate the lower is the proportion of blacks by town
cor(Boston$crim, Boston$lstat) #positive correlation, higher % of lower-status population - higher crime rate
cor(Boston$crim, Boston$rad) #strong positive corr. The higher the accesibility to radial highway, the higher is the crime rate.
# Out:
# [1] -0.3850639
# [1] 0.4556215
# [1] 0.6255051

# %%
#d)

# %%
#e) 
table(Boston$chas)
#35 bound and 471 not bound
# Out:
#   0   1
# 471  35

# %%
#f) 
median(Boston$ptratio)
# Out:
# [1] 19.05

# %%
#h) 
library(dplyr)
Boston %>% filter(rm>7) %>% summarise(n()) #64 suburbs above 7 rooms

Boston %>% filter(rm>8) %>% summarise(n()) #13 suburbs above 8 rooms

hist(Boston$rm)

# the number of suburbs with more than 8 rooms is significantly lower, than those with 7.
# we can in part explain it by the fact, that they must be more expensive, as we see from the scatter below
# and hence lower amount of people have 8 rooms or more per dwelling

cor(Boston$rm, Boston$medv)
plot(Boston$rm, Boston$medv)
# Out:
#   n()
# 1 64
#   n()
# 1 13
# [1] 0.6953599
# Plot with title "Histogram of Boston$rm"
# plot without title

# %% [markdown]
# # Exercise 3 (Chapter 3)

# %% [markdown]
# a) option iii is correct.

# %% [markdown]
# # Exercise 10 (chapter 3)

# %%
library(ISLR)
summary(Carseats)
# Out:
#      Sales          CompPrice       Income        Advertising
#  Min.   : 0.000   Min.   : 77   Min.   : 21.00   Min.   : 0.000
#  1st Qu.: 5.390   1st Qu.:115   1st Qu.: 42.75   1st Qu.: 0.000
#  Median : 7.490   Median :125   Median : 69.00   Median : 5.000
#  Mean   : 7.496   Mean   :125   Mean   : 68.66   Mean   : 6.635
#  3rd Qu.: 9.320   3rd Qu.:135   3rd Qu.: 91.00   3rd Qu.:12.000
#  Max.   :16.270   Max.   :175   Max.   :120.00   Max.   :29.000
#    Population        Price        ShelveLoc        Age          Education
#  Min.   : 10.0   Min.   : 24.0   Bad   : 96   Min.   :25.00   Min.   :10.0
#  1st Qu.:139.0   1st Qu.:100.0   Good  : 85   1st Qu.:39.75   1st Qu.:12.0
#  Median :272.0   Median :117.0   Medium:219   Median :54.50   Median :14.0
#  Mean   :264.8   Mean   :115.8                Mean   :53.32   Mean   :13.9
#  3rd Qu.:398.5   3rd Qu.:131.0                3rd Qu.:66.00   3rd Qu.:16.0
#  Max.   :509.0   Max.   :191.0                Max.   :80.00   Max.   :18.0
# ...

# %%
#a) 
ex10_a <- lm(Sales ~ Price+Urban+US, data = Carseats)
summary(ex10_a)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %% [markdown]
# #b)
# intercept estimate represent the average when all other predictors are not taken into consideration

# %%
#d) 
ex10_d <- lm(Sales ~ ., data = Carseats)
summary(ex10_d)

#we can reject null hypothesis for all values of t greater than ~1. 
#That is everything BUT population, education, urbanYes, UsYes
# Out:
# Call:
# lm(formula = Sales ~ ., data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8692 -0.6908  0.0211  0.6636  3.4115
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.6606231  0.6034487   9.380  < 2e-16 ***
# CompPrice        0.0928153  0.0041477  22.378  < 2e-16 ***
# Income           0.0158028  0.0018451   8.565 2.58e-16 ***
# Advertising      0.1230951  0.0111237  11.066  < 2e-16 ***
# Population       0.0002079  0.0003705   0.561    0.575
# Price           -0.0953579  0.0026711 -35.700  < 2e-16 ***
# ShelveLocGood    4.8501827  0.1531100  31.678  < 2e-16 ***
# ShelveLocMedium  1.9567148  0.1261056  15.516  < 2e-16 ***
# Age             -0.0460452  0.0031817 -14.472  < 2e-16 ***
# Education       -0.0211018  0.0197205  -1.070    0.285
# UrbanYes         0.1228864  0.1129761   1.088    0.277
# USYes           -0.1840928  0.1498423  -1.229    0.220
# ---
# ...

# %%
#e) 
ex10_e <- lm(Sales ~ .-Education-Urban-US-Population, data = Carseats)
summary(ex10_e)
# Out:
# Call:
# lm(formula = Sales ~ . - Education - Urban - US - Population,
#     data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.7728 -0.6954  0.0282  0.6732  3.3292
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.475226   0.505005   10.84   <2e-16 ***
# CompPrice        0.092571   0.004123   22.45   <2e-16 ***
# Income           0.015785   0.001838    8.59   <2e-16 ***
# Advertising      0.115903   0.007724   15.01   <2e-16 ***
# Price           -0.095319   0.002670  -35.70   <2e-16 ***
# ShelveLocGood    4.835675   0.152499   31.71   <2e-16 ***
# ShelveLocMedium  1.951993   0.125375   15.57   <2e-16 ***
# Age             -0.046128   0.003177  -14.52   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.019 on 392 degrees of freedom
# Multiple R-squared:  0.872,	Adjusted R-squared:  0.8697
# F-statistic: 381.4 on 7 and 392 DF,  p-value: < 2.2e-16

# %% [markdown]
# f) f statistic is higher
# Multiple R and R squared insignificantly lower
# DF of RSE go up
# Considering that we took out the variables that do not contribute to predicition the later model is better

# %%
#g
confint(ex10_e)
# Out:
#                 2.5 %       97.5 %
# (Intercept)      4.48236820  6.46808427
# CompPrice        0.08446498  0.10067795
# Income           0.01217210  0.01939784
# Advertising      0.10071856  0.13108825
# Price           -0.10056844 -0.09006946
# ShelveLocGood    4.53585700  5.13549250
# ShelveLocMedium  1.70550103  2.19848429
# Age             -0.05237301 -0.03988204
